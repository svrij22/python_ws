# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df1 = pd.read_csv('data/icu_data_28_0.1.csv', sep =',')
df2 = pd.read_csv('data/icu_data_33_02.csv', sep =',')
df3 = pd.read_csv('data/icu_data_38_03.csv', sep =',')
df4 = pd.read_csv('data/icu_data_43_04.csv', sep =',')
df5 = pd.read_csv('data/icu_data_48_05.csv', sep =',')

# %%
df = pd.concat([df1, df2, df3, df4, df5], axis=0)
df
# Out:
#       Unnamed: 0       distribution bed_amount  denied  covid_denied  \
# 0              0    [4, 4, 4, 9, 7]       [28]    1600           101
# 1              1   [4, 4, 4, 10, 6]       [28]    1642           175
# 2              2   [4, 4, 4, 11, 5]       [28]    1679           248
# 3              3   [4, 4, 4, 12, 4]       [28]    1584           277
# 4              4   [4, 4, 4, 13, 3]       [28]    1652           372
# ...          ...                ...        ...     ...           ...
# 1741        1741  [14, 6, 4, 4, 20]       [48]    1517          1201
# 1742        1742  [15, 4, 4, 4, 21]       [48]    1598          1077
# 1743        1743  [15, 4, 4, 5, 20]       [48]    1494          1224
# 1744        1744  [15, 4, 5, 4, 20]       [48]    1268          1148
# 1745        1745  [15, 5, 4, 4, 20]       [48]    1719          1337
#
#       waiting_time  occupancy  admissioned  failed_reschedules  \
# 0            93306  68.170254         3272                  17
# ...
